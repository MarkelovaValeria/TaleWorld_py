# %% [markdown]
# **Aspect-Based Sentiment Analysis (ABSA) - Model ABSA**

# %% [markdown]
# *імпорти*

# %%
def main():
    # підготовка даних
    # розподілення тексту на теми за допомогою LDA та 
    # імпорт попередніх даних
    # реалізація моделі
    return
